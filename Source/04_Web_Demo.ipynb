# %% [markdown]
# # Web Demo

# %%
from farfetch import Farfetch

# %%
# Start new web demonstration
ff          = Farfetch()
correlation = ff.load_content_similarity_matrix("../Data/content_similarity_matrix_GMC.pkl")
ff.start_demo()
# Out:
# Total number of product ratings:   21641
# Total number of in-stock ratings:  16105
# Total number of unique customers:  9667
# Total number of unique products:   13518

# %%
# Clear recommendation history and go to homepage
n_factors = 10
reg_all   = 0.1
ff.new_user(n_factors, reg_all)
# Out:
# Please enter your name:
# John
# Current user: flatiron_John
# Please enter a product rating on 1 to 5 scale:
# 1
# Please enter a product rating on 1 to 5 scale:
# 2
# Please enter a product rating on 1 to 5 scale:
# 3
# Please enter a product rating on 1 to 5 scale:
# 4
# Please enter a product rating on 1 to 5 scale:
# 5
# Please enter a product rating on 1 to 5 scale:
# 1
# Please enter a product rating on 1 to 5 scale:
# 2
# Please enter a product rating on 1 to 5 scale:
# 3
# Please enter a product rating on 1 to 5 scale:
# 4
# Please enter a product rating on 1 to 5 scale:
# 5
# Please enter a product rating on 1 to 5 scale:
# 1
# Please enter a product rating on 1 to 5 scale:
# 2
# Please enter a product rating on 1 to 5 scale:
# 3
# Please enter a product rating on 1 to 5 scale:
# 4
# Please enter a product rating on 1 to 5 scale:
# 5
# Please enter a product rating on 1 to 5 scale:
# 0
#                                                   URL  \
# 0   https://www.farfetch.com/shopping/women/gucci-...
# 1   https://www.farfetch.com/shopping/women/adidas...
# 2   https://www.farfetch.com/shopping/women/adidas...
# 3   https://www.farfetch.com/shopping/women/dolce-...
# 4   https://www.farfetch.com/shopping/women/gucci-...
# 5   https://www.farfetch.com/shopping/women/dolce-...
# 6   https://www.farfetch.com/shopping/women/adidas...
# 7   https://www.farfetch.com/shopping/women/prada-...
# 8   https://www.farfetch.com/shopping/women/miu-mi...
# 9   https://www.farfetch.com/shopping/women/givenc...
# 10  https://www.farfetch.com/shopping/women/gucci-...
# 11  https://www.farfetch.com/shopping/women/buffal...
# 12  https://www.farfetch.com/shopping/women/givenc...
# 13  https://www.farfetch.com/shopping/women/common...
# 14  https://www.farfetch.com/shopping/women/off-wh...
# 15  https://www.farfetch.com/shopping/women/gucci-...
# 16  https://www.farfetch.com/shopping/women/comme-...
#
#                                               Product Original Discount  \
# 0                   Leather belt with double G buckle      460        0
# 1                               Alphaedge 4D sneakers      317        0
# 2               white and black Pod S31 mesh sneakers      103       50
# 3                            logo label print T-shirt      643        0
# 4                     Ace embroidered low-top sneaker      650        0
# 5                              Sorrento logo sneakers      697        0
# 6                  Calabasas stripe print sweat pants      121       50
# 7                                   platform sneakers      650        0
# 8                               bow detail ballerinas      650        0
# 9                                logo matelassé mules      650        0
# 10                     Fringe leather Horsebit slides      650        0
# 11                                  platform sneakers      230       30
# 12                                 logo band sneakers      500        0
# 13                 Original Achilles leather sneakers      349        0
# 14              black and yellow industrial logo belt      225        0
# 15                       Soho small leather disco bag     1190        0
# 16  x Converse Chuck Taylor multi heart 1970s hi-t...      135        0
#
#    On Sale Gender        Made In                Designer     Category  \
# 0      460  Women  Made in Italy                   Gucci  Accessories
# 1      317    Men       Imported                  Adidas        Shoes
# 2       52    Men       Imported                  Adidas        Shoes
# 3      643    Men  Made in Italy         Dolce & Gabbana     Clothing
# 4      650  Women  Made in Italy                   Gucci        Shoes
# 5      697    Men  Made in Italy         Dolce & Gabbana        Shoes
# 6       61    Men       Imported                  Adidas     Clothing
# 7      650  Women  Made in Italy                   Prada        Shoes
# 8      650  Women  Made in Italy                 Miu Miu        Shoes
# 9      650  Women  Made in Italy                Givenchy        Shoes
# 10     650  Women  Made in Italy                   Gucci        Shoes
# 11     161  Women       Imported                 Buffalo        Shoes
# 12     500  Women       Imported                Givenchy        Shoes
# 13     349  Women  Made in Italy         Common Projects        Shoes
# 14     225    Men  Made in Italy               Off-White  Accessories
# 15    1190  Women  Made in Italy                   Gucci         Bags
# 16     135  Women       Imported  Comme Des Garçons Play        Shoes
#
#    Total Ratings User Rating                    Recommended By
# 0             15           1               Most Rated Products
# 1             10           2              Best One Subcategory
# 2              8           3              Best One Subcategory
# 3              4           4           Best Nine Subcategories
# 4              5           5           Best Nine Subcategories
# 5              5           1           Best Nine Subcategories
# 6             10           2           Best Nine Subcategories
# 7              1           3  Content-Based Pearson Similarity
# 8              1          -1  Content-Based Pearson Similarity
# 9              2           4  Content-Based Pearson Similarity
# 10             1           5  Content-Based Pearson Similarity
# 11            13           1      Singular Value Decomposition
# 12             3           2      Singular Value Decomposition
# 13             5           3      Singular Value Decomposition
# 14             5           4      Singular Value Decomposition
# 15             3           5      Singular Value Decomposition
# 16             5           1      Singular Value Decomposition

# %%
# Close web browser and demonstration
ff.end_demo()

# %%
# Query recommender history item
ff.recommender_system.recommender_history['URL'].iloc[-1]
# Out:
# 'https://www.farfetch.com/shopping/women/comme-des-garcons-play-x-converse-chuck-taylor-multi-heart-1970s-hi-top-sneakers-item-13907827.aspx'
