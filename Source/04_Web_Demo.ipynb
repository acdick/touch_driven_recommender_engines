# %% [markdown]
# # Web Demo

# %%
from farfetch import Farfetch

# %%
ff          = Farfetch()
correlation = ff.load_content_similarity_matrix("../Data/content_similarity_matrix_GMC.pkl")
# Out:
# Total number of product ratings:   21641
# Total number of in-stock ratings:  16105
# Total number of unique customers:  9667
# Total number of unique products:   13518

# %%
# Start new web demonstration
ff.start_demo()

# %%
# Show next recommendation
ff.next_recommendation()
ff.recommender_system.recommender_history
# Out:
# Please enter a product rating on 1 to 5 scale:
# 3
#                                                  URL  \
# 0  https://www.farfetch.com/shopping/women/gucci-...
# 1  https://www.farfetch.com/shopping/women/adidas...
# 2  https://www.farfetch.com/shopping/women/adidas...
# 3  https://www.farfetch.com/shopping/women/dolce-...
# 4  https://www.farfetch.com/shopping/women/gucci-...
# 5  https://www.farfetch.com/shopping/women/dolce-...
# 6  https://www.farfetch.com/shopping/women/comme-...
# 7  https://www.farfetch.com/shopping/women/off-wh...
# 8  https://www.farfetch.com/shopping/women/adidas...
# 9  https://www.farfetch.com/shopping/women/buffal...
#
#                                  Product Original Discount Gender  \
# 0      Leather belt with double G buckle      460        0  Women
# 1                  Alphaedge 4D sneakers      317        0    Men
# 2  white and black Pod S31 mesh sneakers      103       50    Men
# 3  black crown logo print cotton t shirt      427        0    Men
# 4        Ace embroidered low-top sneaker      650        0  Women
# 5                 Sorrento logo sneakers      697        0    Men
# 6   Spalwart X Comme Des Garçon sneakers      317        0    Men
# 7            Vulcanized striped sneakers      315        0    Men
# 8  X Yeezy 700 V2 Geode low-top sneakers      314        0    Men
# 9                      platform sneakers      230       30  Women
#
#          Made In                 Designer     Category Total Ratings  \
# 0  Made in Italy                    Gucci  Accessories            15
# 1       Imported                   Adidas        Shoes            10
# 2       Imported                   Adidas        Shoes             8
# 3       Imported          Dolce & Gabbana     Clothing             4
# 4  Made in Italy                    Gucci        Shoes             5
# 5  Made in Italy          Dolce & Gabbana        Shoes             5
# 6       Imported  Comme Des Garçons Shirt        Shoes             1
# 7       Imported                Off-White        Shoes             2
# 8       Imported                   Adidas        Shoes             1
# 9       Imported                  Buffalo        Shoes            13
#
#   User Rating                    Recommended By
# 0           4                        Most Rated
# 1           5                   Best Nine Depth
# 2           2                   Best Nine Depth
# 3           5                 Best Nine Breadth
# 4           3                 Best Nine Breadth
# 5           1                 Best Nine Breadth
# 6           2  Content-Based Pearson Similarity
# 7           5  Content-Based Pearson Similarity
# 8           4  Content-Based Pearson Similarity
# 9           3                        Most Rated

# %%
# Clear recommendation history and go to homepage
ff.new_user()
ff.recommender_system.recommender_history

# %%
# Close web browser and demonstration
ff.end_demo()
