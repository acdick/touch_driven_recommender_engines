# %% [markdown]
# # Recommender Systems

# %%
from   farfetch import Farfetch
import pandas   as     pd
import numpy    as     np

# %%
ff = Farfetch()
# Out:
# Total number of product ratings:   21641
# Total number of in-stock ratings:  16105
# Total number of unique customers:  9667
# Total number of unique products:   13518

# %% [markdown]
# ## Unpersonalized: Most Rated Single Item

# %%
for i in range(3):
    print(ff.most_rated())
    ff.update_last_rating(np.random.randint(low=1, high=6))
# Out:
# {'URL': 'https://www.farfetch.com/shopping/women/gucci-leather-belt-with-double-g-buckle-item-12132461.aspx', 'Product': 'Leather belt with double G buckle', 'Designer': 'Gucci', 'Category': 'Accessories', 'Total Ratings': 15, 'User Rating': -1, 'Recommended By': 'Most Rated'}
# {'URL': 'https://www.farfetch.com/shopping/women/buffalo-platform-sneakers-item-12971255.aspx', 'Product': 'platform sneakers', 'Designer': 'Buffalo', 'Category': 'Shoes', 'Total Ratings': 13, 'User Rating': -1, 'Recommended By': 'Most Rated'}
# {'URL': 'https://www.farfetch.com/shopping/women/kenzo-tiger-print-t-shirt-item-13283300.aspx', 'Product': 'Tiger print T-shirt', 'Designer': 'Kenzo', 'Category': 'Clothing', 'Total Ratings': 10, 'User Rating': -1, 'Recommended By': 'Most Rated'}

# %%
ff.recommender_system.recommender_history
# Out:
#                                                  URL  \
# 0  https://www.farfetch.com/shopping/women/gucci-...
# 1  https://www.farfetch.com/shopping/women/buffal...
# 2  https://www.farfetch.com/shopping/women/kenzo-...
#
#                              Product Designer     Category Total Ratings  \
# 0  Leather belt with double G buckle    Gucci  Accessories            15
# 1                  platform sneakers  Buffalo        Shoes            13
# 2                Tiger print T-shirt    Kenzo     Clothing            10
#
#   User Rating Recommended By
# 0           5     Most Rated
# 1           5     Most Rated
# 2           1     Most Rated

# %% [markdown]
# ## Unpersonalized: Best Nine by Designer and Category

# %%
ff.best_nine()
# Out:
# [('Adidas', 'Shoes', 375),
#  ('Dolce & Gabbana', 'Clothing', 205),
#  ('Gucci', 'Shoes', 153),
#  ('Dolce & Gabbana', 'Shoes', 131),
#  ('Adidas', 'Clothing', 83),
#  ('Gucci', 'Bags', 78),
#  ('Gucci', 'Clothing', 52),
#  ('Dolce & Gabbana', 'Bags', 50),
#  ('Adidas', 'Bags', 3)]

# %%
for i in range(9):
    print(ff.best_nine_breadth())
    ff.update_last_rating(np.random.randint(low=1, high=6))
# Out:
# {'URL': 'https://www.farfetch.com/shopping/women/adidas-alphaedge-4d-sneakers-item-13655756.aspx', 'Product': 'Alphaedge 4D sneakers', 'Designer': 'Adidas', 'Category': 'Shoes', 'Total Ratings': 10, 'User Rating': -1, 'Recommended By': 'Best Nine Breadth'}
# {'URL': 'https://www.farfetch.com/shopping/women/dolce-gabbana-logo-label-print-t-shirt-item-13518817.aspx', 'Product': 'logo label print T-shirt', 'Designer': 'Dolce & Gabbana', 'Category': 'Clothing', 'Total Ratings': 4, 'User Rating': -1, 'Recommended By': 'Best Nine Breadth'}
# {'URL': 'https://www.farfetch.com/shopping/women/gucci-ace-embroidered-low-top-sneaker-item-12156637.aspx', 'Product': 'Ace embroidered low-top sneaker', 'Designer': 'Gucci', 'Category': 'Shoes', 'Total Ratings': 5, 'User Rating': -1, 'Recommended By': 'Best Nine Breadth'}
# {'URL': 'https://www.farfetch.com/shopping/women/dolce-gabbana-sorrento-logo-sneakers-item-12506574.aspx', 'Product': 'Sorrento logo sneakers', 'Designer': 'Dolce & Gabbana', 'Category': 'Shoes', 'Total Ratings': 5, 'User Rating': -1, 'Recommended By': 'Best Nine Breadth'}
# {'URL': 'https://www.farfetch.com/shopping/women/adidas-calabasas-stripe-print-sweat-pants-item-13497529.aspx', 'Product': 'Calabasas stripe print sweat pants', 'Designer': 'Adidas', 'Category': 'Clothing', 'Total Ratings': 10, 'User Rating': -1, 'Recommended By': 'Best Nine Breadth'}
# {'URL': 'https://www.farfetch.com/shopping/women/gucci-gg-marmont-matelasse-leather-super-mini-bag-item-12331477.aspx', 'Product': 'GG Marmont matelassé leather super mini bag', 'Designer': 'Gucci', 'Category': 'Bags', 'Total Ratings': 7, 'User Rating': -1, 'Recommended By': 'Best Nine Breadth'}
# {'URL': 'https://www.farfetch.com/shopping/women/gucci-interlocking-g-tights-item-12789787.aspx', 'Product': 'Interlocking G tights', 'Designer': 'Gucci', 'Category': 'Clothing', 'Total Ratings': 2, 'User Rating': -1, 'Recommended By': 'Best Nine Breadth'}
# {'URL': 'https://www.farfetch.com/shopping/women/dolce-gabbana-devotion-tote-bag-item-13736321.aspx', 'Product': 'Devotion tote bag', 'Designer': 'Dolce & Gabbana', 'Category': 'Bags', 'Total Ratings': 4, 'User Rating': -1, 'Recommended By': 'Best Nine Breadth'}
# {'URL': 'https://www.farfetch.com/shopping/women/adidas-shell-crossbody-bag-item-13631450.aspx', 'Product': 'shell crossbody bag', 'Designer': 'Adidas', 'Category': 'Bags', 'Total Ratings': 2, 'User Rating': -1, 'Recommended By': 'Best Nine Breadth'}

# %%
ff.recommender_system.recommender_history
# Out:
#                                                   URL  \
# 0   https://www.farfetch.com/shopping/women/gucci-...
# 1   https://www.farfetch.com/shopping/women/buffal...
# 2   https://www.farfetch.com/shopping/women/kenzo-...
# 3   https://www.farfetch.com/shopping/women/adidas...
# 4   https://www.farfetch.com/shopping/women/dolce-...
# 5   https://www.farfetch.com/shopping/women/gucci-...
# 6   https://www.farfetch.com/shopping/women/dolce-...
# 7   https://www.farfetch.com/shopping/women/adidas...
# 8   https://www.farfetch.com/shopping/women/gucci-...
# 9   https://www.farfetch.com/shopping/women/gucci-...
# 10  https://www.farfetch.com/shopping/women/dolce-...
# 11  https://www.farfetch.com/shopping/women/adidas...
#
#                                         Product         Designer     Category  \
# 0             Leather belt with double G buckle            Gucci  Accessories
# 1                             platform sneakers          Buffalo        Shoes
# 2                           Tiger print T-shirt            Kenzo     Clothing
# 3                         Alphaedge 4D sneakers           Adidas        Shoes
# 4                      logo label print T-shirt  Dolce & Gabbana     Clothing
# 5               Ace embroidered low-top sneaker            Gucci        Shoes
# 6                        Sorrento logo sneakers  Dolce & Gabbana        Shoes
# 7            Calabasas stripe print sweat pants           Adidas     Clothing
# 8   GG Marmont matelassé leather super mini bag            Gucci         Bags
# 9                         Interlocking G tights            Gucci     Clothing
# 10                            Devotion tote bag  Dolce & Gabbana         Bags
# 11                          shell crossbody bag           Adidas         Bags
#
#    Total Ratings User Rating     Recommended By
# 0             15           5         Most Rated
# 1             13           5         Most Rated
# 2             10           1         Most Rated
# 3             10           3  Best Nine Breadth
# 4              4           3  Best Nine Breadth
# 5              5           4  Best Nine Breadth
# 6              5           5  Best Nine Breadth
# 7             10           5  Best Nine Breadth
# 8              7           3  Best Nine Breadth
# 9              2           3  Best Nine Breadth
# 10             4           3  Best Nine Breadth
# 11             2           4  Best Nine Breadth

# %%
for i in range(3):
    print(ff.best_nine_depth())
    ff.update_last_rating(np.random.randint(low=1, high=6))
# Out:
# {'URL': 'https://www.farfetch.com/shopping/women/adidas-white-and-black-pod-s31-mesh-sneakers-item-13348208.aspx', 'Product': 'white and black Pod S31 mesh sneakers', 'Designer': 'Adidas', 'Category': 'Shoes', 'Total Ratings': 8, 'User Rating': -1, 'Recommended By': 'Best Nine Depth'}
# {'URL': 'https://www.farfetch.com/shopping/women/adidas-black-white-and-grey-nite-jogger-leather-sneakers-item-13655790.aspx', 'Product': 'black, white and grey nite jogger leather sneakers', 'Designer': 'Adidas', 'Category': 'Shoes', 'Total Ratings': 5, 'User Rating': -1, 'Recommended By': 'Best Nine Depth'}
# {'URL': 'https://www.farfetch.com/shopping/women/adidas-adidas-x-yeezy-boost-350-v2-cream-white-item-12960328.aspx', 'Product': 'adidas x Yeezy Boost 350 V2 Cream White', 'Designer': 'Adidas', 'Category': 'Shoes', 'Total Ratings': 5, 'User Rating': -1, 'Recommended By': 'Best Nine Depth'}

# %%
ff.recommender_system.recommender_history
# Out:
#                                                   URL  \
# 0   https://www.farfetch.com/shopping/women/gucci-...
# 1   https://www.farfetch.com/shopping/women/buffal...
# 2   https://www.farfetch.com/shopping/women/kenzo-...
# 3   https://www.farfetch.com/shopping/women/adidas...
# 4   https://www.farfetch.com/shopping/women/dolce-...
# 5   https://www.farfetch.com/shopping/women/gucci-...
# 6   https://www.farfetch.com/shopping/women/dolce-...
# 7   https://www.farfetch.com/shopping/women/adidas...
# 8   https://www.farfetch.com/shopping/women/gucci-...
# 9   https://www.farfetch.com/shopping/women/gucci-...
# 10  https://www.farfetch.com/shopping/women/dolce-...
# 11  https://www.farfetch.com/shopping/women/adidas...
# 12  https://www.farfetch.com/shopping/women/adidas...
# 13  https://www.farfetch.com/shopping/women/adidas...
# 14  https://www.farfetch.com/shopping/women/adidas...
#
#                                               Product         Designer  \
# 0                   Leather belt with double G buckle            Gucci
# 1                                   platform sneakers          Buffalo
# 2                                 Tiger print T-shirt            Kenzo
# 3                               Alphaedge 4D sneakers           Adidas
# 4                            logo label print T-shirt  Dolce & Gabbana
# 5                     Ace embroidered low-top sneaker            Gucci
# 6                              Sorrento logo sneakers  Dolce & Gabbana
# 7                  Calabasas stripe print sweat pants           Adidas
# 8         GG Marmont matelassé leather super mini bag            Gucci
# 9                               Interlocking G tights            Gucci
# 10                                  Devotion tote bag  Dolce & Gabbana
# 11                                shell crossbody bag           Adidas
# 12              white and black Pod S31 mesh sneakers           Adidas
# 13  black, white and grey nite jogger leather snea...           Adidas
# 14            adidas x Yeezy Boost 350 V2 Cream White           Adidas
#
#        Category Total Ratings User Rating     Recommended By
# 0   Accessories            15           5         Most Rated
# 1         Shoes            13           5         Most Rated
# 2      Clothing            10           1         Most Rated
# 3         Shoes            10           3  Best Nine Breadth
# 4      Clothing             4           3  Best Nine Breadth
# 5         Shoes             5           4  Best Nine Breadth
# 6         Shoes             5           5  Best Nine Breadth
# 7      Clothing            10           5  Best Nine Breadth
# 8          Bags             7           3  Best Nine Breadth
# 9      Clothing             2           3  Best Nine Breadth
# 10         Bags             4           3  Best Nine Breadth
# 11         Bags             2           4  Best Nine Breadth
# 12        Shoes             8           2    Best Nine Depth
# 13        Shoes             5           1    Best Nine Depth
# 14        Shoes             5           2    Best Nine Depth

# %% [markdown]
# ## Content-Based: Product Similarity

# %%
correlation = ff.load_content_similarity_matrix("../Data/content_similarity_matrix_GMC.pkl")
print(correlation.shape)
correlation.head()
# Out:
# (13518, 13518)
# URL                                                 https://www.farfetch.com/shopping/women/valentino-valentino-garavani-open-sneakers-item-13563167.aspx  \
# URL
# https://www.farfetch.com/shopping/women/valenti...                                           1.000000
# https://www.farfetch.com/shopping/women/joseph-...                                           0.980703
# https://www.farfetch.com/shopping/women/joseph-...                                           0.988200
# https://www.farfetch.com/shopping/women/joseph-...                                           0.988200
# https://www.farfetch.com/shopping/women/lela-ro...                                           0.999793
#
# URL                                                 https://www.farfetch.com/shopping/women/joseph-slim-fit-trousers-item-13558158.aspx  \
# URL
# https://www.farfetch.com/shopping/women/valenti...                                           0.980703
# https://www.farfetch.com/shopping/women/joseph-...                                           1.000000
# https://www.farfetch.com/shopping/women/joseph-...                                           0.999075
# https://www.farfetch.com/shopping/women/joseph-...                                           0.999075
# https://www.farfetch.com/shopping/women/lela-ro...                                           0.984452
#
# URL                                                 https://www.farfetch.com/shopping/women/joseph-slim-fit-tank-top-item-13814471.aspx  \
# URL
# https://www.farfetch.com/shopping/women/valenti...                                           0.988200
# https://www.farfetch.com/shopping/women/joseph-...                                           0.999075
# https://www.farfetch.com/shopping/women/joseph-...                                           1.000000
# https://www.farfetch.com/shopping/women/joseph-...                                           1.000000
# https://www.farfetch.com/shopping/women/lela-ro...                                           0.991092
#
# URL                                                 https://www.farfetch.com/shopping/women/joseph-scoop-neck-vest-top-item-13814472.aspx  \
# URL
# https://www.farfetch.com/shopping/women/valenti...                                           0.988200
# https://www.farfetch.com/shopping/women/joseph-...                                           0.999075
# https://www.farfetch.com/shopping/women/joseph-...                                           1.000000
# https://www.farfetch.com/shopping/women/joseph-...                                           1.000000
# https://www.farfetch.com/shopping/women/lela-ro...                                           0
# https://www.farfetch.com/shopping/women/lela-ro...                                           0.999760
#
# URL                                                 https://www.farfetch.com/shopping/women/prada-turtleneck-fitted-jumper-item-13418237.aspx  \
# URL
# https://www.farfetch.com/shopping/women/valenti...                                           0.999998
# https://www.farfetch.com/shopping/women/joseph-...                                           0.980715
# https://www.farfetch.com/shopping/women/joseph-...                                           0.988210
# https://www.farfetch.com/shopping/women/joseph-...                                           0.988210
# https://www.farfetch.com/shopping/women/lela-ro...                                           0.999796
#
# URL                                                 https://www.farfetch.com/shopping/women/max-mara-one-shoulder-jumpsuit-item-13851424.aspx  \
# URL
# https://www.farfetch.com/shopping/women/valenti...                                           0.999866
# https://www.farfetch.com/shopping/women/joseph-...                                           0.983745
# https://www.farfetch.com/shopping/women/joseph-...                                           0.990555
# https://www.farfetch.com/shopping/women/joseph-...                                           0.990555
# https://www.farfetch.com/shopping/women/lela-ro...                                           0.999990
#
# URL                                                 https://www.farfetch.com/shopping/women/yuul-yie-mi-pump-slingback-strap-pumps-item-13063614.aspx  \
# URL
# https://www.farfetch.com/shopping/women/valenti...                                           0.994510
# https://www.farfetch.com/shopping/women/joseph-...                                           0.995769
# https://www.farfetch.com/shopping/women/joseph-...                                           0.998794
# https://www.farfetch.com/shopping/women/joseph-...                                           0.998794
# https://www.farfetch.com/shopping/women/lela-ro...                                           0.996416
#
# URL                                                 https://www.farfetch.com/shopping/women/saint-laurent-monogram-wallet-on-chain-item-12332221.aspx  \
# URL
# https://www.farfetch.com/shopping/women/valenti...                                           0.999998
# https://www.farfetch.com/shopping/women/joseph-...                                           0.980716
# https://www.farfetch.com/shopping/women/joseph-...                                           0.988210
# https://www.farfetch.com/shopping/women/joseph-...                                           0.988210
# https://www.farfetch.com/shopping/women/lela-ro...                                           0.999797
#
# URL                                                 https://www.farfetch.com/shopping/women/marsell-paraccia-hi-top-sneakers-item-13007717.aspx  \
# URL
# https://www.farfetch.com/shopping/women/valenti...                                           0.998605
# https://www.farfetch.com/shopping/women/joseph-...                                           0.989642
# https://www.farfetch.com/shopping/women/joseph-...                                           0.994894
# https://www.farfetch.com/shopping/women/joseph-...                                           0.994894
# https://www.farfetch.com/shopping/women/lela-ro...                                           0.999467
#
# URL                                                 https://www.farfetch.com/shopping/women/steffen-schraut-flared-denim-skirt-item-13700157.aspx
# URL
# https://www.farfetch.com/shopping/women/valenti...                                           0.990342
# https://www.farfetch.com/shopping/women/joseph-...                                           0.998331
# https://www.farfetch.com/shopping/women/joseph-...                                           0.999890
# https://www.farfetch.com/shopping/women/joseph-...                                           0.999890
# https://www.farfetch.com/shopping/women/lela-ro...                                           0.992939
#
# [5 rows x 13518 columns]

# %%
for i in range(3):
    print(ff.content_based_similarity())
    ff.update_last_rating(np.random.randint(low=1, high=6))
# Out:
# {'URL': 'https://www.farfetch.com/shopping/women/gucci-leather-belt-with-double-g-buckle-item-12562759.aspx', 'Product': 'Leather belt with Double G buckle', 'Designer': 'Gucci', 'Category': 'Accessories', 'Total Ratings': 5, 'User Rating': -1, 'Recommended By': 'Content-Based Similarity'}
# {'URL': 'https://www.farfetch.com/shopping/women/gucci-brown-leather-gg-logo-belt-item-13452546.aspx', 'Product': 'Leather belt with Double G buckle', 'Designer': 'Gucci', 'Category': 'Accessories', 'Total Ratings': 1, 'User Rating': -1, 'Recommended By': 'Content-Based Similarity'}
# {'URL': 'https://www.farfetch.com/shopping/women/gucci-double-g-belt-item-11400457.aspx', 'Product': "'Double G' belt", 'Designer': 'Gucci', 'Category': 'Accessories', 'Total Ratings': 10, 'User Rating': -1, 'Recommended By': 'Content-Based Similarity'}

# %%
ff.recommender_system.recommender_history
# Out:
#                                                   URL  \
# %%
from surprise                       import Reader, Dataset
from surprise.model_selection       import cross_validate
from surprise.prediction_algorithms import KNNWithMeans, KNNBasic, KNNBaseline
import numpy                        as np

# %%
utility_matrix.head()

# %%
reader  = Reader()
data    = Dataset.load_from_df(utility_matrix, reader)
dataset = data.build_full_trainset()

# %%
# cross validating with KNNBasic
knn_basic    = KNNBasic(sim_options = {'name': 'pearson', 'user_based': True})
cv_knn_basic = cross_validate(knn_basic, data, n_jobs = -1)

# %%
for i in cv_knn_basic.items():
    print(i)
print('-----------------------')
print(np.mean(cv_knn_basic['test_rmse']))

# %%
# cross validating with KNNBaseline
knn_baseline    = KNNBaseline(sim_options={'name': 'pearson', 'user_based': True})
cv_knn_baseline = cross_validate(knn_baseline, data)

# %%
for i in cv_knn_baseline.items():
    print(i)

np.mean(cv_knn_baseline['test_rmse'])

# %% [markdown]
# ## Collaborative Filtering: Matrix Factorization

# %%
from surprise.model_selection       import GridSearchCV
from surprise.prediction_algorithms import SVD

## Perform a gridsearch with SVD
params  = {'n_factors': [20,50,100],
          'reg_all':    [0.02,0.05,0.1]}
g_s_svd = GridSearchCV(SVD,param_grid=params,n_jobs=-1)
g_s_svd.fit(data)

print(g_s_svd.best_score)
print(g_s_svd.best_params)

# %%
svd = SVD(n_factors= 20, reg_all=0.02)
svd.fit(dataset)

# %%
svd.predict(2,2)

# %%
def movie_rater(movie_df,num, genre=None):
    userID = 1000
    rating_list = []
    while num > 0:
        if genre:
            movie = movie_df[movie_df['genres'].str.contains(genre)].sample(1)
        else:
            movie = movie_df.sample(1)
        print(movie)
        rating = input('How do you rate this movie on a scale of 1-5, press n if you have not seen :\n')
        if rating == 'n':
            continue
        else:
            rating_one_movie = {'userId':userID,'movieId':movie['movieId'].values[0],'rating':rating}
            rating_list.append(rating_one_movie) 
            num -= 1
    return rating_listb

# %%
user_rating = movie_rater(df_movies,4,'Comedy')

# %%
user_rating

# %%
## add the new ratings to the original ratings DataFrame
new_ratings_df = new_df.append(user_rating,ignore_index=True)
new_data = Dataset.load_from_df(new_ratings_df,reader)

# %%
# train a model using the new combined DataFrame
svd_ = SVD(n_factors= 50, reg_all=0.05)
svd_.fit(new_data.build_full_trainset())

# %%
# make predictions for the user
# you'll probably want to create a list of tuples in the format (movie_id, predicted_score)
list_of_movies = []
for m_id in new_df['movieId'].unique():
    list_of_movies.append( (m_id,svd_.predict(1000,m_id)[3]))

# %%
# order the predictions from highest to lowest rated
ranked_movies = sorted(list_of_movies,key=lambda x:x[1],reverse=True)

# %%
# return the top n recommendations using the 
def recommended_movies(user_ratings,movie_title_df,n):
        for idx, rec in enumerate(user_ratings):
            title = movie_title_df.loc[movie_title_df['movieId'] == int(rec[0])]['title']
            print('Recommendation # ',idx+1,': ',title,'\n')
            n-= 1
            if n == 0:
                break
            
recommended_movies(ranked_movies,df_movies,5)
