# %% [markdown]
# # Exploratory Data Analysis

# %%
from   farfetch          import Farfetch
import pandas            as     pd
import matplotlib.pyplot as     plt
import seaborn           as     sns
sns.set_style("darkgrid")

# %%
ff = Farfetch()
# Out:
# Total number of product ratings:   21641
# Total number of in-stock ratings:  16105
# Total number of unique customers:  9667
# Total number of unique products:   13518

# %% [markdown]
# ## In-Stock Product Reviews

# %%
# check utility matrix for recommender systems
utility_matrix, in_stock_reviews, users, items = ff.get_utility_matrix()
in_stock_reviews.head()
# Out:
# Total number of product ratings:   21641
# Total number of in-stock ratings:  16105
# Total number of unique customers:  9667
# Total number of unique products:   13518
#               User                                         Item  \
# 0        Pitchanun  Valentino, Valentino Garavani Open sneakers
# 1        Pitchanun  Valentino, Valentino Garavani Open sneakers
# 2  Marcel G.Torres  Valentino, Valentino Garavani Open sneakers
# 3    Ebba Hellberg  Valentino, Valentino Garavani Open sneakers
# 4              林寶鳳                    Joseph, slim-fit trousers
#
#                                                  URL  Rating  Category  \
# 0  https://www.farfetch.com/shopping/women/valent...     5.0     Shoes
# 1  https://www.farfetch.com/shopping/women/valent...     5.0     Shoes
# 2  https://www.farfetch.com/shopping/women/valent...     4.0     Shoes
# 3  https://www.farfetch.com/shopping/women/valent...     5.0     Shoes
# 4  https://www.farfetch.com/shopping/women/joseph...     5.0  Clothing
#
#              Color   Designer  Discount Gender        Made In  On Sale  \
# 0  JN5 BIANCO BLUE  Valentino         0  Women  Made in Italy      695
# 1  JN5 BIANCO BLUE  Valentino         0  Women  Made in Italy      695
# 2  JN5 BIANCO BLUE  Valentino         0  Women  Made in Italy      695
# 3  JN5 BIANCO BLUE  Valentino         0  Women  Made in Italy      695
# 4       0211 SMOKE     Joseph        50  Women       Imported      126
#
#    Original                           Product        Style Subcategory
# 0       695  Valentino Garavani Open sneakers  RW2S0781BLU    Sneakers
# 1       695  Valentino Garavani Open sneakers  RW2S0781BLU    Sneakers
# 2       695  Valentino Garavani Open sneakers  RW2S0781BLU    Sneakers
# 3       695  Valentino Garavani Open sneakers  RW2S0781BLU    Sneakers
# 4       252                 slim-fit trousers     JP000631  Slim Pants

# %%
items.nunique()
# Out:
# Item           12375
# URL            13518
# Category          29
# Color           7788
# Designer        1184
# Discount          16
# Gender             3
# Made In            5
# On Sale         1227
# Original        1300
# Product        10687
# Style          12596
# Subcategory      374
# dtype: int64

# %%
# print count and frequency plots of each data column
fig, axes = plt.subplots(nrows=len(in_stock_reviews.columns),
                       ncols=2,
                       figsize=(16,80), constrained_layout=True)

for i in range(len(in_stock_reviews.columns)):
    column = in_stock_reviews.columns[i]
    print(column + '--> total groups: ' + str(len(in_stock_reviews[column].value_counts())))
    print(str(in_stock_reviews[column].value_counts().iloc[:10]) + '\n')
    
    g=sns.countplot(in_stock_reviews[column],
                    order=in_stock_reviews[column].value_counts().iloc[:10].index,
                    alpha=0.8, ax=axes[i,0])
    g.set_xticklabels(rotation=90,labels=in_stock_reviews[column].value_counts().iloc[:10].index)
    
    print(column + '--> frequency distribution: '
          + str(len(in_stock_reviews.groupby(column)[column].count().value_counts())))
    print(str(in_stock_reviews.groupby(column)[column]
              .count().value_counts().iloc[:10].sort_index(ascending=True)) + '\n\n')
    
    in_stock_reviews.groupby(column)[column].count().hist(bins=20, ax=axes[i,1])
    axes[i,1].set(xlabel='Frequency', ylabel='Number of groups')
# Out:
# User--> total groups: 9667
# LUCAS NGUYEN    60
# Olga            36
# Elena           36
# Vladislav       34
# zhangxudong     31
# soojin yoon     27
# Natalia         27
# Fatemah         27
# monirula        24
# Ekaterina       23
# Name: User, dtype: int64
#
# User--> frequency distribution: 29
# 1     6693
# 2     1673
# 3      616
# 4      290
# 5      148
# 6       79
# 7       53
# 8       24
# 9       26
# 11      13
# Name: User, dtype: int64
#
#
# Item--> total groups: 12375
# Golden Goose, Superstar sneakers                38
# Kenzo, Tiger print T-shirt                      35
# Alexander McQueen, oversized sole sneakers      27
# Gucci, Leather belt with double G buckle        25
# Balmain, logo print T-shirt                     20
# Valentino, Valentino Garavani Open sneakers     19
# Stella McCartney, Eclypse sneakers              17
# Buffalo, platform sneakers                      16
# Dolce & Gabbana, Portofino sneakers             16
# Valentino, Valentino Garavani Rockstud pumps    15
# Name: Item, dtype: int64
#
# Item--> frequency distribution: 23
# 1     10251
# 2      1431
# 3       396
# 4       134
# 5        57
# 6        32
# 7        22
# 8        12
# 9         9
# 10       10
# Name: Item, dtype: int64
#
#
# URL--> total groups: 13518
# https://www.farfetch.com/shopping/women/gucci-leather-belt-with-double-g-buckle-item-12132461.aspx                            15
# https://www.farfetch.com/shopping/women/buffalo-platform-sneakers-item-12971255.aspx                                          13
# https://www.farfetch.com/shopping/women/alexander-mcqueen-oversized-sole-sneakers-item-13525833.aspx                          10
# https://www.farfetch.com/shopping/women/gucci-double-g-belt-item-11400457.aspx                                                10
# https://www.farfetch.com/shopping/women/kenzo-tiger-print-t-shirt-item-13283300.aspx                                          10
# https://www.farfetch.com/shopping/women/adidas-calabasas-stripe-print-sweat-pants-item-13497529.aspx                          10
# https://www.farfetch.com/shopping/women/adidas-alphaedge-4d-sneakers-item-13655756.aspx                                       10
# https://www.farfetch.com/shopping/women/golden-goose-white-hi-star-zebra-print-leather-low-top-sneakers-item-13539850.aspx     8
# https://www.farfetch.com/shopping/women/balenciaga-black-speed-knitted-high-top-sock-sneakers-item-13331990.aspx               8
# https://www.farfetch.com/shopping/women/balenciaga-black-triple-s-leather-sneakers-item-12967005.aspx                          8
# Name: URL, dtype: int64
#
# URL--> frequency distribution: 11
# 1     11699
# 2      1361
# 3       299
# 4        91
# 5        36
# 6        15
# 7         5
# 8         5
# 10        5
# 15        1
# Name: URL, dtype: int64
#
#
# Rating--> total groups: 5
# 5.0    13326
# 4.0     1613
# 1.0      500
# 3.0      491
# 2.0      175
# Name: Rating, dtype: int64
#
# Rating--> frequency distribution: 5
# 175      1
# 491      1
# 500      1
# 1613     1
# 13326    1
# Name: Rating, dtype: int64
#
#
# Category--> total groups: 29
# Clothing             7229
# Shoes                4907
# Bags                 1566
# Accessories           943
# Girls Clothing        381
# Boys Clothing         338
# Jewelry               162
# Activewear            110
# Baby Boy Clothing      67
# Boys Shoes             65
# Name: Category, dtype: int64
#
# Category--> frequency distribution: 24
# 1       3
# 2       1
# 3       3
# 4       1
# 5       1
# 8       2
# 63      1
# 65      1
# 162     1
# 1566    1
# Name: Category, dtype: int64
#
#
# Color--> total groups: 7788
# BLACK         774
# WHITE         347
# 001 BLACK     255
# 1000 BLACK    241
# 100 WHITE     140
# BLUE          130
# 900 BLACK      85
# 99 BLACK       85
# 01 WHITE       74
# RED            74
# Name: Color, dtype: int64
#
# Color--> frequency distribution: 55
# 1     5698
# 2     1155
# 3      384
# 4      182
# 5       91
# 6       61
# 7       27
# 8       44
# 9       17
# 10      17
# Name: Color, dtype: int64
#
#
# Designer--> total groups: 1184
# Adidas                  486
# Gucci                   435
# Dolce & Gabbana         433
# Dsquared2               345
# Off-White               338
# Michael Michael Kors    325
# Kenzo                   317
# Saint Laurent           304
# Stella McCartney        229
# Nike                    218
# Name: Designer, dtype: int64
#
# Designer--> frequency distribution: 104
# 1     381
# 2     172
# 3     113
# 4      83
# 5      40
# 6      50
# 7      33
# 8      22
# 9      18
# 15     17
# Name: Designer, dtype: int64
#
#
# Discount--> total groups: 16
# 0     6397
# 40    2233
# 50    2031
# 30    1974
# 20    1227
# 10     488
# 35     481
# 60     432
# 25     361
# 15     293
# Name: Discount, dtype: int64
#
# Discount--> frequency distribution: 16
# 5       1
# 25      1
# 62      1
# 85      1
# 432     1
# 1227    1
# 1974    1
# 2031    1
# 2233    1
# 6397    1
# Name: Discount, dtype: int64
#
#
# Gender--> total groups: 3
# Women    8995
# Men      5959
# Kids     1151
# Name: Gender, dtype: int64
#
# Gender--> frequency distribution: 3
# 1151    1
# 5959    1
# 8995    1
# Name: Gender, dtype: int64
#
#
# Made In--> total groups: 5
# Imported                  8997
# Made in Italy             6678
# Made in United States      208
# Made in United Kingdom     120
# Made in France             102
# Name: Made In, dtype: int64
#
# Made In--> frequency distribution: 5
# 102     1
# 120     1
# 208     1
# 6678    1
# 8997    1
# Name: Made In, dtype: int64
#
#
# On Sale--> total groups: 1227
# 135    136
# 95     126
# 495    111
# 295    100
# 100     86
# 490     85
# 48      84
# 73      77
# 195     77
# 225     76
# Name: On Sale, dtype: int64
#
# On Sale--> frequency distribution: 78
# 1     317
# 2     159
# 3      85
# 4      60
# 5      36
# 6      41
# 7      29
# 8      29
# 9      22
# 11     20
# Name: On Sale, dtype: int64
#
#
# Original--> total groups: 1300
# 495    202
# 295    164
# 95     127
# 695    122
# 595    119
# 135    119
# 490    115
# 195    114
# 100    112
# 350    107
# Name: Original, dtype: int64
#
# Original--> frequency distribution: 91
# 1     373
# 2     168
# 3      98
# 4      54
# 5      59
# 6      37
# 7      33
# 9      31
# 10     26
# 11     23
# Name: Original, dtype: int64
#
#
# Product--> total groups: 10687
# logo print T-shirt          232
# logo T-shirt                 98
# Superstar sneakers           49
# lace-up sneakers             38
# Tiger print T-shirt          36
# logo print sweatshirt        35
# graphic print T-shirt        35
# printed T-shirt              32
# oversized sole sneakers      31
# embroidered logo T-shirt     30
# Name: Product, dtype: int64
#
# Product--> frequency distribution: 31
# 1     8374
# 2     1410
# 3      428
# 4      175
# 5       97
# 6       57
# 7       31
# 8       19
# 9       21
# 10      17
# Name: Product, dtype: int64
#
#
# Style--> total groups: 12596
# F955TS0504YA      19
# 553680WHGP5       18
# 400593AP00T       17
# 476433DSVRT       16
# 409416CVE0T       16
# 553770WHGP7       14
# 133914BLANCO01    13
# RF11075I042       13
# RF01322I170       12
# 542023W1GB1       12
# Name: Style, dtype: int64
#
# Style--> frequency distribution: 18
# 1     10454
# 2      1485
# 3       369
# 4       141
# 5        66
# 6        31
# 7        12
# 8         8
# 9         8
# 10        9
# Name: Style, dtype: int64
#
#
# Subcategory--> total groups: 374
# Sneakers                    1328
# Low-Tops                    1184
# T-Shirts                    1149
# Sandals                      719
# T-Shirts & Jersey Shirts     662
# Shirts                       439
# Day Dresses                  409
# Tote Bags                    401
# Shoulder Bags                370
# Pumps                        307
# Name: Subcategory, dtype: int64
#
# Subcategory--> frequency distribution: 96
# 1     67
# 2     42
# 3     27
# 4     24
# 5     23
# 6     10
# 7     10
# 8     14
# 12     7
# 13    10
# Name: Subcategory, dtype: int64

# %%
# show top designers
df = in_stock_reviews.loc[(in_stock_reviews['Designer'] == 'Adidas') |
                          (in_stock_reviews['Designer'] == 'Gucci') |
                          (in_stock_reviews['Designer'] == 'Dolce & Gabbana')]
df.head()
# Out:
#                     User                                               Item  \
# 15  Bruna PigattoCasarin  Gucci, GG Marmont matelassé leather super mini...
# 16  Bruna PigattoCasarin  Gucci, GG Marmont matelassé leather super mini...
# 17     Cindy Schlickmann  Gucci, GG Marmont matelassé leather super mini...
# 18     Renata GaiaoJorge  Gucci, GG Marmont matelassé leather super mini...
# 19               Luciana  Gucci, GG Marmont matelassé leather super mini...
#
#                                                   URL  Rating Category  \
# 15  https://www.farfetch.com/shopping/women/gucci-...     5.0     Bags
# 16  https://www.farfetch.com/shopping/women/gucci-...     5.0     Bags
# 17  https://www.farfetch.com/shopping/women/gucci-...     5.0     Bags
# 18  https://www.farfetch.com/shopping/women/gucci-...     4.0     Bags
# 19  https://www.farfetch.com/shopping/women/gucci-...     5.0     Bags
#
#         Color Designer  Discount Gender        Made In  On Sale  Original  \
# 15  1000 nero    Gucci         0  Women  Made in Italy      890       890
# 16  1000 nero    Gucci         0  Women  Made in Italy      890       890
# 17  1000 nero    Gucci         0  Women  Made in Italy      890       890
# 18  1000 nero    Gucci         0  Women  Made in Italy      890       890
# 19  1000 nero    Gucci         0  Women  Made in Italy      890       890
#
#                                         Product        Style Subcategory
# 15  GG Marmont matelassé leather super mini bag  476433DSVRT   Mini Bags
# 16  GG Marmont matelassé leather super mini bag  476433DSVRT   Mini Bags
# 17  GG Marmont matelassé leather super mini bag  476433DSVRT   Mini Bags
# 18  GG Marmont matelassé leather super mini bag  476433DSVRT   Mini Bags
# 19  GG Marmont matelassé leather super mini bag  476433DSVRT   Mini Bags

# %%
# user-product sparsity matrix
utility_matrix           = ff.get_utility_matrix()[0]
utility_matrix['Rating'] = 1
utility_matrix           = utility_matrix.drop_duplicates()
print(utility_matrix.pivot(index='URL', columns='User', values='Rating').shape)

# sparsity
n_products = utility_matrix.pivot(index='URL', columns='User', values='Rating').shape[0]
n_users    = utility_matrix.pivot(index='URL', columns='User', values='Rating').shape[1]
print('Sparsity:             ' + str(1 - (utility_matrix.shape[0] / (n_products * n_users))))
print('One product per user: ' + str(1 - 1/9667))
print('One user per product: ' + str(1 - 1/13518))

sns.set_context("notebook", font_scale=1.6, rc={"lines.linewidth":3, 'lines.markersize': 15})
sns.set_style('whitegrid', {'font.family':'serif', 'font.serif':'Times New Roman'})
fig, axes = plt.subplots(figsize=(16,16))
plt.spy(utility_matrix.pivot(index='User', columns='URL', values='Rating'), markersize=0.5)

axes.set_title(label='99.988% Matrix Sparsity of Customer-Product Utility Matrix (16,105 Product Reviews)')
axes.set(xlabel='13,518 Unique Products', ylabel='9,667 Unique Customers')
plt.gca().xaxis.tick_bottom()
# Out:
# Total number of product ratings:   21641
# Total number of in-stock ratings:  16105
# Total number of unique customers:  9667
# Total number of unique products:   13518
# (13518, 9667)
# Sparsity:             0.9998776003759945
# One product per user: 0.9998965552911968
# One user per product: 0.9999260245598461
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:7738: RuntimeWarning: invalid value encountered in greater
#   nonzero = np.abs(Z) > precision

# %%
# heatmap of similarity matrix
# similarity_matrix = pd.read_pickle("../Data/content_similarity_matrix_GMC.pkl")
# print(similarity_matrix.shape)
# similarity_matrix

# fig, axes = plt.subplots(figsize=(8,16))
# sns.heatmap(similarity_matrix)
